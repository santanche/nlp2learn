# %% [markdown]
# # Regular Expressions in Python

# %% [markdown]
# ## `search`

# %%
import re

pattern = re.compile(r"tumors")

test_string = "The CT scan revealed tumors in the lungs"

match = pattern.search(test_string)

if match is not None:
  print(f"Match was found at {match.start()}-{match.end()}: {match.group()}")
# Out:
# Match was found at 21-27: tumors

# %% [markdown]
# ## `finditer`

# %%
import re

pattern = re.compile(r"[1234567890]")

test_string = "The patient's BP was 120/80"

matches = pattern.finditer(test_string)

for match_num, match in enumerate(matches, start=1):
    print(f"Match {match_num} was found at {match.start()}-{match.end()}: {match.group()}")
    
    for group_num, group in enumerate(match.groups(), start=1):
        print(f"Group {group_num} found at {match.start(group_num)}-{match.end(group_num)}: {group}")
# Out:
# Match 1 was found at 21-22: 1
# Match 2 was found at 22-23: 2
# Match 3 was found at 23-24: 0
# Match 4 was found at 25-26: 8
# Match 5 was found at 26-27: 0
